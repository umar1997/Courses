# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()
# %matplotlib notebook

# %%
plt.style.use('seaborn-colorblind')

# %%
np.random.seed(123)
dates = pd.date_range('1/1/2017', periods = 365)
print (dates)
# one = list(np.random.randn(365).cumsum(0))
# two = list(np.random.randn(365).cumsum(0) + 20)
# three = list(np.random.randn(365).cumsum(0) - 20)
# dict = []
# for i in range(0,365):
#     dict.append([one[i],two[i],three[i]])
# df = pd.DataFrame(dict,index=dates, columns = ['A','B','C'])
# df.plot()
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
# df.plot('A','B', kind = 'scatter')
ax = df.plot.scatter('A','C', c ='B', s =df['B'], colormap = 'viridis')
ax.set_aspect('equal') # Set aspect ratio
df.plot.box()
df.plot.hist(alpha=0.7)
df.plot.kde() # Kernel density estimation
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
pd.tools.plotting.scatter_matrix(df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026281524208>,
# ...
#       dtype=object)

# %%
import seaborn as sns
np.random.seed(1234)

v1 = pd.Series(np.random.normal(0,10,1000), name = 'v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name = 'v2')
               
plt.figure()
plt.hist(v1, alpha = 0.7, bins= np.arange(-50,150,5), label='v1')
plt.hist(v2, alpha = 0.7, bins= np.arange(-50,150,5), label='v2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist([v1,v2], histtype='barstacked', normed=True)
v3 = np.concatenate((v1,v2))
sns.kdeplot(v3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure()
sns.distplot(v3, hist_kws={'color':'Teal'},kde_kws={'color':'Navy'})
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.jointplot(v1,v2,alpha=0.4) # First
grid = sns.jointplot(v1,v2,alpha=0.4)
grid.ax_joint.set_aspect('equal') # Second
sns.jointplot(v1,v2,alpha=0.4,kind='hex') # Third
# Out:
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">

# %%
sns.set_style('white')
sns.jointplot(v1,v2, kind = 'kde', space = 0)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.pairplot(df,diag_kind = 'kde')
# Out:
# <img src="data:image/png;base64,..." width="936.8">

# %%
iris = pd.read_csv('iris.csv')
print(iris.head())
sns.pairplot(iris,hue = 'variety',diag_kind = 'kde')
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# <img src="data:image/png;base64,..." width="1388.8">

# %%
plt.figure()
plt.subplot(1,2,1)
sns.swarmplot('variety','petal.length',data= iris)
plt.subplot(1,2,2)
sns.violinplot('variety','petal.length',data= iris)
# Out:
# <img src="data:image/png;base64,..." width="640">
